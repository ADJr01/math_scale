# %%
# imprts
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# Params
n1 = 30 # samples in dataset 1
n2 = 40 # sample in dataset 2
num1 = 1 # population mean in dataset1
num2 = 2 # population mean in dataset2
