# %%
# imports
import numpy as np
import torch

# %% [markdown]
# # Mean Calculation

# %%
# Dataset
sample_data = [2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,200]
n=len(sample_data)

# %%
mean1 = np.mean(sample_data)
mean2 = np.sum(sample_data)/n
print(mean1)
print(mean2)
# Out:
# 11.428571428571429
# 11.428571428571429

# %% [markdown]
# # Variance Calculation

# %%
v = np.var(sample_data,ddof=1)
v1 = (1/(n-1)) * np.sum((sample_data-mean1)**2)
print(v)
print(v1)
# Out:
# 1866.8571428571431
# 1866.8571428571431

# %%
np.sum(sample_data-mean1)
# Out:
# np.float64(5.684341886080802e-14)
